# %% [markdown]
# **Descriptive Analytics for Numerical Columns**

# %% [markdown]
# ●	Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58e92b00-11b6-40be-9478-b1e85463a311" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58e92b00-11b6-40be-9478-b1e85463a311">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sales=pd.read_csv('sales_data_with_discounts.csv')
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
sales.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
sales.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
sales_num=sales.select_dtypes(include=['number'])

# %%
sales_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Volume             450 non-null    int64
#  1   Avg Price          450 non-null    int64
#  2   Total Sales Value  450 non-null    int64
#  3   Discount Rate (%)  450 non-null    float64
#  4   Discount Amount    450 non-null    float64
#  5   Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 21.2 KB

# %%
sales_num.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# Here is this Numerical Columns
#
# 1. Volume
# 2. Avg Price
# 3. Total Sales Value

# %%
# For Volume Mean,Medain , Mode
mean=round(sales['Volume'].mean(),2)
print("Mean of the sales for Volume is :",mean)

median=sales['Volume'].median()
print("Median of the sales for Volume is :",median)

mode=sales['Volume'].mode()
print("Mode of the sales for Volume is :",mode)

std=sales['Volume'].std()
print("Standard deviation of the sales for Volume is :",std)
# Out:
# Mean of the sales for Volume is : 5.07
# Median of the sales for Volume is : 4.0
# Mode of the sales for Volume is : 0    3
# Name: Volume, dtype: int64
# Standard deviation of the sales for Volume is : 4.231602391213923

# %%
# For Avg Price Mean,Medain , Mode
mean=round(sales['Avg Price'].mean(),2)
print("Mean of the sales for Avg Price is :",mean)

median=sales['Avg Price'].median()
print("Median of the sales for Avg Price is :",median)

mode=sales['Avg Price'].mode()
print("Mode of the sales for Avg Price is :",mode)

std=sales['Avg Price'].std()
print("Standard deviation of the sales for Avg Price is :",std)
# Out:
# Mean of the sales for Avg Price is : 10453.43
# Median of the sales for Avg Price is : 1450.0
# Mode of the sales for Avg Price is : 0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64
# Standard deviation of the sales for Avg Price is : 18079.90483993647

# %%
# For Total Sales Value Mean,Medain , Mode
mean=round(sales['Total Sales Value'].mean(),2)
print("Mean of the sales for Total Sales Value is :",mean)

median=sales['Total Sales Value'].median()
print("Median of the sales for Total Sales Value is :",median)

mode=sales['Total Sales Value'].mode()
print("Mode of the sales for Total Sales Value is :",mode)

std=sales['Total Sales Value'].std()
print("Standard deviation of the sales for Total Sales Value is :",std)
# Out:
# Mean of the sales for Total Sales Value is : 33812.84
# Median of the sales for Total Sales Value is : 5700.0
# Mode of the sales for Total Sales Value is : 0    24300
# Name: Total Sales Value, dtype: int64
# Standard deviation of the sales for Total Sales Value is : 50535.07417255325

# %%
# For Discount Rate (%) Mean,Medain , Mode
mean=round(sales['Discount Rate (%)'].mean(),2)
print("Mean of the sales for Discount Rate (%) is :",mean)

median=sales['Discount Rate (%)'].median()
print("Median of the sales for Discount Rate (%) is :",median)

mode=sales['Discount Rate (%)'].mode()
print("Mode of the sales for Discount Rate (%) is :",mode)

std=sales['Discount Rate (%)'].std()
print("Standard deviation of the sales for Discount Rate (%) is :",std)
# Out:
# Mean of the sales for Discount Rate (%) is : 15.16
# Median of the sales for Discount Rate (%) is : 16.57776564929597
# Mode of the sales for Discount Rate (%) is : 0       5.007822
# 1       5.055218
# 2       5.059801
# 3       5.072124
# 4       5.084108
#          ...
# 445    19.940610
# 446    19.965340
# 447    19.976879
# 448    19.982257
# 449    19.992407
# Name: Discount Rate (%), Length: 450, dtype: float64
# Standard deviation of the sales for Discount Rate (%) is : 4.22060215332551

# %%
# For Discount Amount Mean,Medain , Mode
mean=round(sales['Discount Amount'].mean(),2)
print("Mean of the sales for Discount Amount is :",mean)

median=sales['Discount Amount'].median()
print("Median of the sales for Discount Amount is :",median)

mode=sales['Discount Amount'].mode()
print("Mode of the sales for Discount Amount is :",mode)

std=sales['Discount Amount'].std()
print("Standard deviation of the sales for Discount Amount is :",std)
# Out:
# Mean of the sales for Discount Amount is : 3346.5
# Median of the sales for Discount Amount is : 988.9337332382784
# Mode of the sales for Discount Amount is : 0         69.177942
# 1         73.025199
# 2         93.649161
# 3         94.682735
# 4        102.705757
#            ...
# 445    17900.983733
# 446    21153.498820
# 447    21496.675367
# 448    25328.224204
# 449    25738.022194
# Name: Discount Amount, Length: 450, dtype: float64
# Standard deviation of the sales for Discount Amount is : 4509.902963353998

# %%
# For Net Sales Value Mean,Medain , Mode
mean=round(sales['Net Sales Value'].mean(),2)
print("Mean of the sales for Net Sales Value is :",mean)

median=sales['Net Sales Value'].median()
print("Median of the sales for Net Sales Value is :",median)

mode=sales['Net Sales Value'].mode()
print("Mode of the sales for Net Sales Value is :",mode)

std=sales['Net Sales Value'].std()
print("Standard deviation of the sales for Net Sales Value is :",std)
# Out:
# Mean of the sales for Net Sales Value is : 30466.34
# Median of the sales for Net Sales Value is : 4677.788059301853
# Mode of the sales for Net Sales Value is : 0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# 4         496.607104
#            ...
# 445    162603.186379
# 446    163915.971000
# 447    163967.080070
# 448    166263.161348
# 449    179507.479049
# Name: Net Sales Value, Length: 450, dtype: float64
# Standard deviation of the sales for Net Sales Value is : 46358.65662406695

# %% [markdown]
# Mean: Average value.
#
# Median: Middle value; less affected by outliers.
#
# Mode: Most frequent value.
#
# Standard Deviation: Measure of spread or variability

# %% [markdown]
# **Data Visualiztion**

# %% [markdown]
# Histograms

# %%
sales_num=sales.select_dtypes(include=['number'])

# %%
sales_num.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sales_num.hist(figsize=(12,12),grid=False)
plt.show()

# %%
for col in sales_num:
  skewness=round(sales[col].skew(),2)
  print(f'Skewness of {col}:{skewness}')
# Out:
# Skewness of Volume:2.73
# Skewness of Avg Price:1.91
# Skewness of Total Sales Value:1.53
# Skewness of Discount Rate (%):-1.06
# Skewness of Discount Amount:1.91
# Skewness of Net Sales Value:1.54

# %% [markdown]
# we can observed from above plots
# with respect volume,avg price, discount amount, net sales value  it is postive skewness
# with respect to discount rate negatively present
# we can observe the plots  there are many outlayers

# %%
sales_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Volume             450 non-null    int64
#  1   Avg Price          450 non-null    int64
#  2   Total Sales Value  450 non-null    int64
#  3   Discount Rate (%)  450 non-null    float64
#  4   Discount Amount    450 non-null    float64
#  5   Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 21.2 KB

# %% [markdown]
# **Box Plot**

# %%
plt.figure(figsize=(8,6))
plt.boxplot([sales_num['Volume'], sales_num['Avg Price'], sales_num['Total Sales Value'],sales_num["Discount Rate (%)"],sales_num["Discount Amount"],sales_num["Net Sales Value"]], labels=['Volume', 'Avg Price', 'Total Sales Value',"Discount Rate (%)","Discount Amount","Net Sales Value"])
plt.title("Boxplot of Numerical Columns")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.xticks(rotation=45,ha="right")
plt.show()

# %% [markdown]
# Interquartile Range (IQR)

# %%
columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
for col in columns:
    Q1 = sales_num[col].quantile(0.25)
    Q3 = sales_num[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = sales_num[col][(sales_num[col] < lower_bound) | (sales_num[col] > upper_bound)]

    print(f"Column: {col}")
    print(f"First Quartile (Q1): {Q1}")
    print(f"Third Quartile (Q3): {Q3}")
    print(f"Interquartile Range (IQR): {IQR}")
    print(f"Lower Bound for Outliers: {lower_bound}")
    print(f"Upper Bound for Outliers: {upper_bound}")
    print(f"Outliers in the '{col}' data: {outliers}\n")
# Out:
# Column: Volume
# First Quartile (Q1): 3.0
# Third Quartile (Q3): 6.0
# Interquartile Range (IQR): 3.0
# Lower Bound for Outliers: -1.5
# Upper Bound for Outliers: 10.5
# Outliers in the 'Volume' data: 0      15
# 10     13
# 30     11
# 40     29
# 50     13
# 70     24
# 71     14
# 80     12
# 100    25
# 101    15
# 102    11
# 130    15
# 140    14
# 161    12
# 170    12
# 180    12
# 190    22
# 192    11
# 193    11
# 200    12
# 201    12
# 210    14
# 221    11
# 222    11
# 240    15
# 250    31
# 251    12
# 260    16
# 280    24
# 281    11
# 282    12
# 300    12
# 310    22
# 312    11
# 320    13
# 340    15
# 350    12
# 370    14
# 371    14
# 390    11
# 400    29
# 410    15
# 420    13
# 431    17
# Name: Volume, dtype: int64
#
# Column: Avg Price
# First Quartile (Q1): 465.0
# Third Quartile (Q3): 10100.0
# Interquartile Range (IQR): 9635.0
# Lower Bound for Outliers: -13987.5
# Upper Bound for Outliers: 24552.5
# Outliers in the 'Avg Price' data: 6      49100
# ...

# %% [markdown]
# ●	Bar Chart Analysis for Categorical Column

# %%
sales_cat=sales.select_dtypes(include=['object'])

# %%
sales_cat.head()
# Out:
#          Date       Day  SKU City       BU  Brand       Model
# 0  01-04-2021  Thursday  M01    C  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C  Mobiles   YouM      YM-98

# %%
brand=sales_cat['Brand'].value_counts().reset_index()
brand.columns=["Brand","Count"]

# %%
sns.barplot(brand,x="Brand",y="Count")
# Out:
# <Axes: xlabel='Brand', ylabel='Count'>

# %%
day=sales_cat['Day'].value_counts().reset_index()
day.columns=['Day','Count']

# %%
sns.barplot(day,x='Day',y='Count')
# Out:
# <Axes: xlabel='Day', ylabel='Count'>

# %%
date=sales_cat['Date'].value_counts().reset_index()
date.columns=['Date','Count']
plt.figure(figsize=(10,6))
sns.barplot(date,x="Date",y="Count",width=0.8)
plt.xticks(rotation=45,ha="right")
plt.show()

# %% [markdown]
# Standardization of Numerical Variables

# %%
sales_standarlized=sales.copy()

# %%
for columns in sales.select_dtypes(include="number").columns:
  mean=sales[columns].mean()
  std=sales[columns].std()

  sales_standarlized[columns]=(sales[columns]-mean)/std

# %%
ax=sales_standarlized.hist(figsize=(12,12),grid=False)

# %%
ax=sales_num.hist(figsize=(12,12),grid=False)

# %% [markdown]
# Conversion of Categorical Data into Dummy Variables

# %%
sales_encoded = pd.get_dummies(sales_cat)
print(sales_encoded.head())
# Out:
#    Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  Date_04-04-2021  \
# 0             True            False            False            False
# 1             True            False            False            False
# 2             True            False            False            False
# 3             True            False            False            False
# 4             True            False            False            False
#
#    Date_05-04-2021  Date_06-04-2021  Date_07-04-2021  Date_08-04-2021  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Date_09-04-2021  Date_10-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...
