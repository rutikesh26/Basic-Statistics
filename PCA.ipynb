# %% [markdown]
# ##PCA

# %% [markdown]
# ####Exploratory Data Analysis(EDA):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0             0.28             2.29   5.64  1.04      3.92     1065
# 1             0.26             1.28   4.38  1.05      3.40     1050
# 2             0.30             2.81   5.68  1.03      3.17     1185
# 3             0.24             2.18   7.80  0.86      3.45     1480
# 4             0.39             1.82   4.32  1.04      2.93      735
# ..             ...              ...    ...   ...       ...      ...
# 173           0.52             1.06   7.70  0.64      1.74      740
# 174           0.43             1.41   7.30  0.70      1.56      750
# 175           0.43             1.35  10.20  0.59      1.56      835
# 176           0.53             1.46   9.30  0.60      1.62      840
# 177           0.56             1.35   9.20  0.61      1.60      560
#
# [178 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# std      0.625851    0.998859       0.124453         0.572359    2.318286
# min      0.980000    0.340000       0.130000         0.410000    1.280000
# 25%      1.742500    1.205000       0.270000         1.250000    3.220000
# 50%      2.355000    2.135000       0.340000         1.555000    4.690000
# 75%      2.800000    2.875000       0.437500         1.950000    6.200000
# max      3.880000    5.080000       0.660000         3.580000   13.000000
#
#               Hue    Dilution      Proline
# count  178.000000  178.000000   178.000000
# mean     0.957449    2.611685   746.893258
# std      0.228572    0.709990   314.907474
# min      0.480000    1.270000   278.000000
# 25%      0.782500    1.937500   500.500000
# 50%      0.965000    2.780000   673.500000
# 75%      1.120000    3.170000   985.000000
# max      1.710000    4.000000  1680.000000

# %%
df.dtypes
# Out:
# Type                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
numerical_columns = df.select_dtypes(include=['int64','float64'])

# %%
# Histograms for numerical features
for column in numerical_columns.columns:
  plt.figure(figsize=(10,6))
  sns.histplot(df[column],bins=30,kde=True)
  plt.title(f'Histogram of {column}')
  plt.show()

# %%
# Box plots for each numerical features
for column in numerical_columns.columns:
  plt.figure(figsize=(10,6))
  sns.boxplot(x=df[column])
  plt.title(f'Box Plot of{column}')
  plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(12,8))
correlation_matrix = numerical_columns.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Dimensionality Reduction With PCA

# %%
X = df.drop('Type',axis='columns')
X
# Out:
#      Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0      14.23   1.71  2.43        15.6        127     2.80        3.06
# 1      13.20   1.78  2.14        11.2        100     2.65        2.76
# 2      13.16   2.36  2.67        18.6        101     2.80        3.24
# 3      14.37   1.95  2.50        16.8        113     3.85        3.49
# 4      13.24   2.59  2.87        21.0        118     2.80        2.69
# ..       ...    ...   ...         ...        ...      ...         ...
# 173    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0             0.28             2.29   5.64  1.04      3.92     1065
# 1             0.26             1.28   4.38  1.05      3.40     1050
# 2             0.30             2.81   5.68  1.03      3.17     1185
# 3             0.24             2.18   7.80  0.86      3.45     1480
# 4             0.39             1.82   4.32  1.04      2.93      735
# ..             ...              ...    ...   ...       ...      ...
# 173           0.52             1.06   7.70  0.64      1.74      740
# 174           0.43             1.41   7.30  0.70      1.56      750
# 175           0.43             1.35  10.20  0.59      1.56      835
# 176           0.53             1.46   9.30  0.60      1.62      840
# 177           0.56             1.35   9.20  0.61      1.60      560
#
# [178 rows x 13 columns]

# %%
y = df['Type']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Type, Length: 178, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_standardized  = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_standardized,y,test_size=0.2,random_state=30)

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(X_standardized)
eigenvalues = pca.explained_variance_

# %%
plt.figure(figsize=(8,6))
plt.plot(range(1,len(eigenvalues)+1),eigenvalues,marker='o',linestyle='--')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
pca = PCA(n_components=4)
X_pca = pca.fit_transform(X_standardized)
X_pca
# Out:
# array([[ 3.31675081e+00,  1.44346263e+00, -1.65739045e-01,
#         -2.15631188e-01],
#        [ 2.20946492e+00, -3.33392887e-01, -2.02645737e+00,
#         -2.91358318e-01],
#        [ 2.51674015e+00,  1.03115130e+00,  9.82818670e-01,
#          7.24902309e-01],
#        [ 3.75706561e+00,  2.75637191e+00, -1.76191842e-01,
#          5.67983308e-01],
#        [ 1.00890849e+00,  8.69830821e-01,  2.02668822e+00,
#         -4.09765788e-01],
#        [ 3.05025392e+00,  2.12240111e+00, -6.29395827e-01,
#         -5.15637495e-01],
#        [ 2.44908967e+00,  1.17485013e+00, -9.77094891e-01,
#         -6.58305046e-02],
#        [ 2.05943687e+00,  1.60896307e+00,  1.46281883e-01,
#         -1.19260801e+00],
#        [ 2.51087430e+00,  9.18070957e-01, -1.77096903e+00,
#          5.62703612e-02],
#        [ 2.75362819e+00,  7.89437674e-01, -9.84247490e-01,
#          3.49381568e-01],
#        [ 3.47973668e+00,  1.30233324e+00, -4.22735217e-01,
#          2.68417600e-02],
#        [ 1.75475290e+00,  6.11977229e-01, -1.19087832e+00,
#         -8.90164338e-01],
#        [ 2.11346234e+00,  6.75706339e-01, -8.65086426e-01,
#         -3.56438010e-01],
#        [ 3.45815682e+00,  1.13062988e+00, -1.20427635e+00,
#          1.62458063e-01],
#        [ 4.31278391e+00,  2.09597558e+00, -1.26391275e+00,
#          3.05773190e-01],
#        [ 2.30518820e+00,  1.66255173e+00,  2.17902616e-01,
#         -1.44059003e+00],
#        [ 2.17195527e+00,  2.32730534e+00,  8.31729866e-01,
#         -9.12601275e-01],
#        [ 1.89897118e+00,  1.63136888e+00,  7.94913792e-01,
#         -1.08238039e+00],
#        [ 3.54198508e+00,  2.51834367e+00, -4.85458508e-01,
#         -9.10322807e-01],
#        [ 2.08452220e+00,  1.06113799e+00, -1.64746678e-01,
#          4.84997419e-01],
#        [ 3.12440254e+00,  7.86897106e-01, -3.64887083e-01,
#         -2.55616906e-02],
#        [ 1.08657007e+00,  2.41743551e-01,  9.36961600e-01,
#          1.02990984e+00],
#        [ 2.53522408e+00, -9.18406207e-02, -3.11932659e-01,
#          6.68386112e-01],
#        [-2.73715050e+00,  4.09886271e-01, -1.19040468e+00,
#         -6.63045204e-01],
#        [-3.60486887e+00,  1.80238422e+00, -9.40368613e-02,
#          1.26884047e+00],
#        [-2.88982600e+00,  1.92521861e+00, -7.82322556e-01,
#          1.32472540e+00],
#        [-3.39215608e+00,  1.31187639e+00,  1.60202597e+00,
#         -4.82842144e-01],
#        [-1.04818190e+00,  3.51508969e+00,  1.16003857e+00,
#          9.35329394e-01],
#        [-1.60991228e+00,  2.40663816e+00,  5.48559697e-01,
#          7.54309684e-01],
#        [-3.14313097e+00,  7.38161044e-01, -9.09987239e-02,
#          9.80647845e-01],
#        [-2.24015690e+00,  1.17546529e+00, -1.01376932e-01,
#         -1.16527872e+00],
#        [-2.84767378e+00,  5.56043966e-01,  8.04215218e-01,
#         -8.97888066e-01],
#        [-2.59749706e+00,  6.97965537e-01, -8.84939521e-01,
#         -2.74228748e-01],
#        [-2.94929937e+00,  1.55530896e+00, -9.83400727e-01,
#          1.54803469e-02],
#        [-3.53003227e+00,  8.82526796e-01, -4.66029128e-01,
#          5.80789625e-01],
#        [-2.40611054e+00,  2.59235618e+00,  4.28226211e-01,
#         -1.84335092e-01],
#        [-2.92908473e+00,  1.27444695e+00, -1.21335827e+00,
#          2.95316047e-01],
#        [-2.18141278e+00,  2.07753731e+00,  7.63782552e-01,
#         -3.89593322e-01],
#        [-2.38092779e+00,  2.58866743e+00,  1.41804403e+00,
#          5.88501936e-01],
#        [-3.21161722e+00, -2.51249104e-01, -8.47129152e-01,
#         -2.17065355e-01],
#        [-3.67791872e+00,  8.47747844e-01, -1.33942023e+00,
#         -1.25175865e-01],
#        [-2.46555580e+00,  2.19379830e+00, -9.18780960e-01,
#          1.80249950e-02],
#        [-3.37052415e+00,  2.21628914e+00, -3.42569512e-01,
#          1.05852684e+00],
#        [-2.60195585e+00,  1.75722935e+00,  2.07581355e-01,
#          3.49496422e-01],
#        [-2.67783946e+00,  2.76089913e+00, -9.40941877e-01,
#          3.12034746e-01],
#        [-2.38701709e+00,  2.29734668e+00, -5.50696197e-01,
#         -6.88284548e-01],
#        [-3.20875816e+00,  2.76891957e+00,  1.01391366e+00,
#          5.96903186e-01]])

# %% [markdown]
# ###Clustering with Original Data

# %%
# Finding out the optimal number of clusters
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

#Elbow method
wcss = []
for i in range(1,11):
  kmeans = KMeans(n_clusters = i,init='k-means++',max_iter=300,n_init=10,random_state=0)
  kmeans.fit(X_standardized)
  wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
n_clusters = 3
kmeans = KMeans(n_clusters=n_clusters,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_kmeans = kmeans.fit_predict(X_standardized)

# %%
# Add cluster information to the original dataframe

df['Cluster'] = y_kmeans
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  Cluster
# 0             0.28             2.29   5.64  1.04      3.92     1065        2
# 1             0.26             1.28   4.38  1.05      3.40     1050        2
# 2             0.30             2.81   5.68  1.03      3.17     1185        2
# 3             0.24             2.18   7.80  0.86      3.45     1480        2
# 4             0.39             1.82   4.32  1.04      2.93      735        2
# ..             ...              ...    ...   ...       ...      ...      ...
# 173           0.52             1.06   7.70  0.64      1.74      740        1
# 174           0.43             1.41   7.30  0.70      1.56      750        1
# 175           0.43             1.35  10.20  0.59      1.56      835        1
# 176           0.53             1.46   9.30  0.60      1.62      840        1
# 177           0.56             1.35   9.20  0.61      1.60      560        1
#
# [178 rows x 15 columns]

# %%
plt.scatter(X_standardized[:,0],X_standardized[:,1],c=y_kmeans,s=50,cmap='viridis')

# %%
# Compute the silhouette score
silhoutte_avg = silhouette_score(X_standardized,y_kmeans)
print(f'Silhouette Score:{silhoutte_avg:3f}')
# Out:
# Silhouette Score:0.284859

# %% [markdown]
# #### Clustering with PCA Data

# %%
PCA_components = pd.DataFrame(X_pca)

# %%
wcss = []

for i in range(1,15):
  kmeans = KMeans(n_clusters=i,init='k-means++',random_state=42)
  kmeans.fit(PCA_components)
  wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,15),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
n_clusters = 3
kmeans =KMeans(n_clusters=n_clusters,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_kmeans1 = kmeans.fit_predict(X_pca)

# Add cluster information to the original dataframe
df['Cluster']=y_kmeans1
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  Cluster
# 0             0.28             2.29   5.64  1.04      3.92     1065        0
# 1             0.26             1.28   4.38  1.05      3.40     1050        0
# 2             0.30             2.81   5.68  1.03      3.17     1185        0
# 3             0.24             2.18   7.80  0.86      3.45     1480        0
# 4             0.39             1.82   4.32  1.04      2.93      735        0
# ..             ...              ...    ...   ...       ...      ...      ...
# 173           0.52             1.06   7.70  0.64      1.74      740        1
# 174           0.43             1.41   7.30  0.70      1.56      750        1
# 175           0.43             1.35  10.20  0.59      1.56      835        1
# 176           0.53             1.46   9.30  0.60      1.62      840        1
# 177           0.56             1.35   9.20  0.61      1.60      560        1
#
# [178 rows x 15 columns]

# %%
plt.scatter(X_pca[:,0],X_pca[:,1],c=y_kmeans1,s=50,cmap='viridis')

# %%
# Compute the silhouette score

silhouette_avg = silhouette_score(X_pca,y_kmeans1)
print(f"Silhouette Score: {silhouette_avg:3f}")
# Out:
# Silhouette Score: 0.406597

# %% [markdown]
# ### Comparison and Analysis

# %% [markdown]
# #### 1. Compare clustering result obtained from the original dataset and PCA-transformed data.

# %% [markdown]
# --> The original dataset suffer from high dimensionality,which makes cluster algorithms less effective.Whereas applying PCA reduce the dimensionality to the top 2 or 3 principal components that capture majority of the variance in the data.Running k-means clustering on the PCA-transformed data can reveal clusters based on the most significant variance directions. PCA-transformed data often simplifies the problem by reducing the number of features,which can improve clustering performance and make visualizzation easier.

# %% [markdown]
# ####2. Discuss the similarities or difference observed in the clustering results.

# %% [markdown]
# --> In the original dataset,clusters is less distict or exhibit different shapes due to noise and correlations among fetaures.PCA protect the data in the way that aligns clusters more clearly with the principal componenets.
#
#
# --> PCA-transformed data emphasizes variance in feature combinations rather than individual features,which might change how the clusters are formed compared to using the original features directly.

# %% [markdown]
# ####3.Reflect on the impact of dimensionality reduction on clustering performance.

# %% [markdown]
# --> Dimensionality reduction often leads to improved clustering performance by improving noise and reducing computational complexity.For the wine dataset,this means that the PCA-transformed data might show more coherent clusters because the most important features are emphasized.
#
# --> With fewer dimensions,clustering algorithms like kmeans can be more computationally efficient,potentially leading to faster convergence and less sensitivity to initial conditions.
#
# --> Clustering performance can improve if the principal componenets capture the underlying struture of the data well.However,if PCA discards significant features that are important for distinguishing clusters,the clustering results might be less accurate.

# %% [markdown]
# ####4.Analyse the trade-offs between using PCA and clustering directly on the original dataset.

# %% [markdown]
# Advantages of using PCA:
#
# --> Simplifies the clustering  process the number of features,which can be especially beneficial if the original datasethas many correlated or less informative features.
#
# --> PCA helps to filter out noise and irrelevant features,which can lead to clearer and more distinct clusters.
#
# -->Reducing dimensions to 2 or 3 allows easier visualization and interpretation of clusters,making it easier to understand the clustering reults.
#
# Disadvantages of PCA:
#
# --> PCA may lose some information by focusing oly the directions of maximum variance.If important features for clustering are discarded,this can lead to suboptimal clustering results.
#
# --> The principal components are linear combinations of the original features,which can make it difficult to interpret the cluster in terms of the original features.
#
# -->PCA assumes linear relationshipsbetween features,which may not always capture the true structure of the data,potentially affecting clustering performance.
#
# Clustering Directly on the Original Dataset:
#
# -->Clustering on the original dataset uses all avialable features,preserving the complete information and potentially capturing more nuanced patterns
#
# --> Clustering algorithms may struggle with high-dimensional data due to the curse of dimensionality,where distance metrics become less meaningful and clusters might not be as distinct.

# %% [markdown]
# ### Conclusion and Insights

# %% [markdown]
# #### 1.Summarize the key findings and insights from the assignment.

# %% [markdown]
# Dimensionality Reduction and Clustering: Applying PCA to the wine dataset before clustering generally enhances the clustering process by reducing dimensionality,which simplifies the data and potentially improves cluster separation.PCA helps to capture the most significant variance in fewer dimensions,making it easier to identify and visualize clusters.
#
# Comparison of Clustering Results: Clustering results on PCA- transformed data may show clearer and more distinct clusters compared to clustering on the original high-dimensional dataset.PCA can mitigate issues related to noise and feature redundancy,which can make clusters more interpretable and easier to validate.
#
# Similarities and Differences: While PCA-transformed data often aligns with the major clusters found in the original dataset,it may also alter cluster shapes or boundaries depending on how the principal components capture the datas variance.Key patterns might remain consistent,but detailed cluster structures can vary.
#
# Impact of Dimensionality Reduction: Dimensionality reduction through PCA can improve clustering performance by focusing on the most significant features and reducing computational complexity.However,there is a trade-off between reduced complexity and potential loss of information.

# %% [markdown]
# #####2.Discuss the practical implications of using PCA and clustering in data analysis.

# %% [markdown]
# Enhanced Data Interpretability: PCA reduces the complexity of high-dimensional data, making it easier to interpret and visualize. This can be particularly useful for understanding the underlying structure of data and presenting results in a more comprehensible way.
#
# Improved Clustering Efficiency: Dimensionality reduction can make clustering algorithms more efficient, as fewer dimensions mean reduced computational time and resource usage. This is beneficial for handling large datasets or for speeding up iterative algorithms like k-means.
#
# Noise and Feature Reduction: PCA helps to eliminate noise and irrelevant features, leading to more meaningful clustering results. By focusing on the most significant variance, PCA can improve the quality of the clusters and make the results more reliable.
#
# Information Loss: One practical concern is that PCA can result in the loss of some information, which might be critical for certain applications. This trade-off must be balanced against the benefits of reduced complexity and improved performance.

# %% [markdown]
# ####3.Provide recommendations for when to use each technique based on the analysis conducted.

# %% [markdown]
# When to Use PCA:
#
# High Dimensionality: When working with datasets that have many features, PCA is recommended to reduce dimensionality and simplify the data. This is especially useful when features are correlated or when the dataset is very large.
#
# Computational Efficiency: If computational resources or time are constraints, PCA can be employed to reduce the number of dimensions, making clustering algorithms faster and more manageable.
#
# Visualization Needs: For data visualization purposes, reducing the dataset to 2 or 3 dimensions with PCA can help in creating plots that make clusters easier to visualize and interpret.
#
# Noise Reduction: Use PCA when the dataset contains a lot of noise or redundant features that may obscure the clustering process. PCA’s ability to focus on significant variance can enhance clustering results.
#
# When to Cluster Directly on the Original Dataset:
#
# Preserving Information: If the dataset’s dimensionality is manageable and you believe all features are relevant for clustering, it may be better to cluster directly on the original data to retain all information.
#
# Non-Linear Relationships: If the data has non-linear relationships that PCA might not capture well, consider clustering directly on the original dataset or using other dimensionality reduction techniques that can handle non-linearity, such as t-SNE or UMAP.
#
# Feature Interpretation: When it’s crucial to interpret clusters based on the original features, avoiding PCA can help maintain the direct relationship between clusters and the original data attributes.
